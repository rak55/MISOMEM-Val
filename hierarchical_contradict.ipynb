# %%
from openai import OpenAI, BadRequestError
from openai.types.chat import ChatCompletion
from tenacity import retry, stop_after_attempt, wait_random_exponential
import time
from typing import Optional
import base64
import requests
import json
import os
import re
from tqdm import tqdm
import yaml
from openai import OpenAI
import dataclasses
import textwrap
import pandas as pd
import pickle
from pathlib import Path
import pprint
from collections import defaultdict

# %%
class MinimumDelay:
    def __init__(self, delay: float | int):
        self.delay = delay
        self.start = None

    def __enter__(self):
        self.start = time.time()

    def __exit__(self, exc_type, exc_val, exc_tb):
        end = time.time()
        seconds = end - self.start
        if self.delay > seconds:
            time.sleep(self.delay - seconds)

@retry(wait=wait_random_exponential(min=1, max=90), stop=stop_after_attempt(3))
def chat(client: OpenAI, delay: float | int, **kwargs) -> ChatCompletion | None:
    try:
        with MinimumDelay(delay):
            return client.chat.completions.create(**kwargs)
    except BadRequestError as e:
        print(f"Bad Request: {e}")
        if "safety" in e.message:
            return None
        raise e
    except Exception as e:
        print(f"Exception: {e}")
        raise e
def print_messages(messages):
    for message in messages:
        if isinstance(message["content"], list):
            print(f"{message['role']}:")
            for content in message["content"]:
                if content["type"] == "text":
                    print(content["text"])
                elif content["type"] == "image_url":
                    print("[IMAGE]")
        else:
            print(f"{message['role']}: {message['content']}")
        print()
    print("=========================================")

def read_jsonl(path):
    with open(path, "r") as f:
        for line in f:
            line = line.strip()
            if line:
                ex = json.loads(line)
                yield ex

def write_jsonl(path, data):
    with open(path, "w") as f:
        for ex in data:
            f.write(json.dumps(ex) + "\n")

# Function to encode the image
def encode_image(image_path):
    with open(image_path, "rb") as image_file:
        return base64.b64encode(image_file.read()).decode("utf-8")

# %% [markdown]
# Step 1: HTD

# %%
from pydantic import BaseModel, Field
import instructor

client = instructor.from_openai(OpenAI(api_key=os.environ['OPENAI_API_KEY'], timeout= 90))
class InstructorChatCompletionConfig(BaseModel):
    seed: int = Field(..., description="Random seed for reproducibility")
    delay: int = Field(..., description="Minimum delay between requests in seconds")
    model: str = Field(..., description="Model to use for chat completion")
    max_tokens: int = Field(..., description="Maximum number of tokens in the response")
    temperature: float = Field(..., description="Sampling temperature for response generation")
    system_prompt: str = Field(..., description="System prompt to set the context for the conversation")
    user_prompt: str = Field(..., description="User prompt to initiate the conversation")
    response_format: dict | None = Field(None, description="Expected format of the response")

class Feedback(BaseModel):
    feedback: list[str] = Field(
        description="A list of actions to take to make predicted values more consistent with the value taxonomy."
    )
    is_consistent: bool

# %%
from pydantic import BaseModel, Field
from typing import List


class Level1Value(BaseModel):
    level_1_value: str = Field(
        description="Level 1 Shwartz cultural value applicable to the frame.",
        enum=["Openness to Change", "Self-Enhancement", "Conservation", "Self-Transcendence"]
    )
    rationale: str = Field(description="Rationale explaining why the level 1 value is applicable to the frame.")


class Level2Value(BaseModel):
    level_2_value: str = Field(
        description="Level 2 cultural value applicable to the frame.",
        enum=[
            "Self-direction (thought)",
            "Self-direction (action)",
            "Stimulation",
            "Hedonism",
            "Achievement",
            "Power (dominance)",
            "Power (resources)",
            "Face",
            "Security (personal)",
            "Security (societal)",
            "Tradition",
            "Conformity (rules)",
            "Conformity (interpersonal)",
            "Humility",
            "Benevolence (caring)",
            "Benevolence (dependability)",
            "Universalism (concern)",
            "Universalism (nature)",
            "Universalism (tolerance)",
            "Universalism (objectivity)"
        ]
    )
    rationale: str = Field(description="Rationale explaining why the level 2 value is applicable to the frame.")


class Level3Value(BaseModel):
    level_3_value: str = Field(description="Level 3 cultural value applicable to the frame.", 
            enum=[
                "Be creative",
                "Be curious",
                "Have freedom of thought",
                "Be choosing own goals",
                "Be independent",
                "Have freedom of action",
                "Have privacy",
                "Have an exciting life",
                "Have a varied life",
                "Be daring",
                "Have pleasure",
                "Be ambitious",
                "Have success",
                "Be capable",
                "Be intellectual",
                "Be courageous",
                "Have influence",
                "Have the right to command",
                "Have wealth",
                "Have social recognition",
                "Have a good reputation",
                "Have a sense of belonging",
                "Have good health",
                "Have no debts",
                "Be neat and tidy",
                "Have a comfortable life",
                "Have a safe country",
                "Have a stable society",
                "Be respecting traditions",
                "Be holding religious faith",
                "Be compliant",
                "Be self-disciplined",
                "Be behaving properly",
                "Be polite",
                "Be honoring elders",
                "Be humble",
                "Have life accepted as is",
                "Be helpful",
                "Be honest",
                "Be forgiving",
                "Have the own family secured",
                "Be loving",
                "Be responsible",
                "Have loyalty towards friends",
                "Have equality",
                "Be just",
                "Have a world at peace",
                "Be protecting the environment",
                "Have harmony with nature",
                "Have a world of beauty",
                "Be broadminded",
                "Have the wisdom to accept others",
                "Be logical",
                "Have an objective view"
            ])
    rationale: str = Field(description="Rationale explaining why the level 3 value is applicable to the frame.")


class Values(BaseModel):
    level_1_values: List[Level1Value] = Field(..., alias="level 1 values")
    level_2_values: List[Level2Value] = Field(..., alias="level 2 values")
    level_3_values: List[Level3Value] = Field(..., alias="level 3 values")


class CulturalValues(BaseModel):
    values: Values

class Timestep(BaseModel):
    response: CulturalValues
    feedback: Optional[list[str]] = Field(default_factory=list)
    refined_response: Optional[CulturalValues]


class History(BaseModel):
    history: list[Timestep] = Field(default_factory=list)

    def add(self, code, feedback, refined_code):
        self.history.append(
            Timestep(response=code, feedback=feedback, refined_response=refined_code)
        )
def stop_condition(feedback, history):
    return feedback.is_consistent or len(history.history) >= 3

# %%
config_file_path = 'prompts/hierarchical2.yaml'
with open(config_file_path, 'r') as f:
    config = yaml.safe_load(f)
    config = InstructorChatCompletionConfig(**config)

with open('prompts/feedback.yaml', 'r') as f:
    feedback_config = yaml.safe_load(f)
    feedback_config = InstructorChatCompletionConfig(**feedback_config)

with open('prompts/refine.yaml', 'r') as f:
    refine_config = yaml.safe_load(f)
    refine_config = InstructorChatCompletionConfig(**refine_config)

# %%
def get_valid_level2_actions(level1_action: str) -> list[str]:
    """
    Get valid level 2 actions based on the level 1 action.
    """
    if level1_action == "Openness to Change":
        return["Self-direction (thought)",
                      "Self-direction (action)",
                      "Stimulation",
                      "Hedonism"]   
                    
    elif level1_action == "Self-Enhancement":
        return ["Hedonism", "Achievement",
                      "Power (dominance)",
                      "Power (resources)", "Face"]
    elif level1_action == "Conservation":
        return ["Face","Security (personal)",
                      "Security (societal)",
                      "Tradition",
                      "Conformity (rules)",  
                      "Conformity (interpersonal)",
                      "Humility"]
    elif level1_action == "Self-Transcendence":
        return ["Humility", "Benevolence (caring)",
                "Benevolence (dependability)",
                      "Universalism (concern)",
                      "Universalism (nature)",
                      "Universalism (tolerance)"
                      "Universalism (objectivity)"]
    else:
        return []
    
def get_valid_level3_actions(level2_action: str) -> list[str]:
    """
    Get valid level 3 actions based on the level 2 action.
    """
    if level2_action == "Self-direction (thought)":
        return ["Be creative",
                "Be curious",
                "Have freedom of thought",]
    elif level2_action == "Self-direction (action)":
        return ["Be choosing your own goals",
                "Be independent",
                "Have freedom of action","Have privacy"]
    elif level2_action == "Stimulation":
        return ["Have an exciting life",
                "Have a varied life",
                "Be daring",]
    elif level2_action == "Hedonism":
        return ["Have pleasure"]
    elif level2_action == "Achievement":
        return ["Be ambitious",
                "Have success"
                "Be capable",
                "Be intellectual",
                "Be courageous"]
    elif level2_action == "Power (dominance)":
        return ["Have influence",
                "Have the right to command"]
    elif level2_action == "Power (resources)":
        return ["Have wealth"]
    elif level2_action == "Face":
        return ["Have a social recognition",
                "Have a good reputation",
        ]
    elif level2_action == "Security (personal)":
        return ["Have a sense of belonging",
                "Have good health",
                "Have no debts",
                "Be neat and tidy",
                "Have a comfortable life"]
    elif level2_action == "Security (societal)":
        return ["Have a safe country",
                "Have a stable society",]
    elif level2_action == "Tradition":
        return ["Be respecting traditions",
                "Be holding religious faith"]
    elif level2_action == "Conformity (rules)":
        return ["Be compliant",
                "Be self-disciplined",
                "Be behaving properly",]
    elif level2_action == "Conformity (interpersonal)":
        return ["Be polite",
                "Be honouring elders",]
    elif level2_action == "Humility":
        return ["Be humble",
                "Have life accepted as is"]
    elif level2_action == "Benevolence (caring)":
        return ["Be helpful",
                "Be honest",
                "Be forgiving",
                "Have the own family secured",
                "Be loving"]
    elif level2_action == "Benevolence (dependability)":
        return ["Be responsible",
                "Have loyalty towards friends"]
    elif level2_action == "Universalism (concern)":
        return ["Have equality",
                "Be just",
                "Have a world at peace"]
    elif level2_action == "Universalism (nature)":
        return ["Be protecting the environment",
                "Have harmony with nature",
                "Have a world of beauty"]
    elif level2_action == "Universalism (tolerance)":
        return ["Be broadminded",
                "Have the wisdom to accept others"]
    
    elif level2_action == "Universalism (objectivity)":
        return ["Be logical",
                "Have an objective view"]
    else:
        return []

# %%
def generate_response(config: InstructorChatCompletionConfig, frame: str, prob_def: str, level1: str, level2:str, level3:str):
    with open("cultural_values_taxonomy.yaml", "r") as f:
        values_yaml = f.read()

    sys_prompt = config.system_prompt.strip()
    user_prompt= config.user_prompt.strip()
    final_sys_prompt=sys_prompt.format(values_yaml=values_yaml)
    msg=[{"role": "system", "content": final_sys_prompt},
         {"role": "user", "content": user_prompt.format(Frame=frame, Definition_str=prob_def, level_1_values = level1, level_2_values= level2,
                                                        level_3_values=level3)}]
    #print_messages(msg)
    return client.chat.completions.create(
        model=config.model,
        messages=msg,
        temperature=config.temperature,
        response_model=CulturalValues,
        seed=config.seed
    )

def get_levels_from_response(response: dict) -> dict:
    level1_vals=[]
    level1_rats=[]
    level2_vals=[]
    level2_rats=[]
    level3_vals=[]
    level3_rats=[]
    for l in response.values.level_1_values:
        level1_vals.append(l.level_1_value)
        level1_rats.append(l.rationale)
    for l in response.values.level_2_values:
        level2_vals.append(l.level_2_value)
        level2_rats.append(l.rationale)
    for l in response.values.level_3_values:
        level3_vals.append(l.level_3_value)
        level3_rats.append(l.rationale)

    app_level2_vals = []
    seen = set()

    for val in level1_vals:
        for lvl2 in get_valid_level2_actions(val):
            if lvl2 not in seen:
                seen.add(lvl2)
                app_level2_vals.append(lvl2)

    app_level3_vals = []
    seen = set()
    for val in level2_vals:
        for lvl3 in get_valid_level3_actions(val):
            if lvl3 not in seen:
                app_level3_vals.append(lvl3)
                
    return {"level1_vals": level1_vals, "level1_rats": level1_rats, "level2_vals": level2_vals, "level2_rats": level2_rats, 
            "level3_vals": level3_vals, "level3_rats": level3_rats, "app_level2_vals": app_level2_vals, "app_level3_vals": app_level3_vals}



def generate_feedback(config:InstructorChatCompletionConfig, response: dict, frame: str):
    sys_prompt = config.system_prompt.strip()
    user_prompt = config.user_prompt.strip()

    response_data = get_levels_from_response(response)

    

    final_usr= user_prompt.format(
        Frame=frame,
        level_1_values=response_data['level1_vals'],
        level_1_rationale=response_data['level1_rats'],
        level_2_values=response_data['level2_vals'],
        level_2_rationale=response_data['level2_rats'],
        level_3_values=response_data['level3_vals'],
        level_3_rationale=response_data['level3_rats'],
        app_level_2_values=response_data['app_level2_vals'],
        app_level_3_values= response_data['app_level3_vals'],
    )
    msg = [
        {"role": "system", "content": sys_prompt},
        {"role": "user", "content": final_usr},
    ]
    #print_messages(msg)
    return client.chat.completions.create(
        model=config.model,
        messages=msg,
        temperature=config.temperature,
        response_model=Feedback,
        seed=config.seed
    )

def refine_response(config: InstructorChatCompletionConfig, response: Feedback, response0: dict, frame: str):

    sys_prompt = config.system_prompt.strip()
    user_prompt = config.user_prompt.strip()
    response_data = get_levels_from_response(response0)
    fdbk_str = "\n".join(response.feedback)
    final_usr= user_prompt.format(Frame=frame, level_1_values=response_data['level1_vals'], level_2_values=response_data['level2_vals'], level_3_values=response_data['level3_vals'],
                                  feedback=fdbk_str)
    msg = [{"role": "system", "content": sys_prompt},
              {"role": "user", "content": final_usr}]
    #print_messages(msg)
    return client.chat.completions.create(
        model=config.model,
        messages=msg,
        temperature=config.temperature,
        response_model=CulturalValues,
        seed=config.seed
    )

# %%
import os
import json
base_dir = "final_frames"  # path to your folder

for problem_folder in os.listdir(base_dir):
    folder_path = os.path.join(base_dir, problem_folder)
    values_file = os.path.join(folder_path, "values.jsonl")
    
    if os.path.isdir(folder_path) and os.path.exists(values_file):
        value_dict = {}

        with open(values_file, "r", encoding="utf-8") as f:
            for line in f:
                entry = json.loads(line)
                value_dict[entry["id"]] = entry["response"]

        # Write the dictionary to value_dict.json
        output_file = os.path.join(folder_path, "value_dict.json")
        with open(output_file, "w", encoding="utf-8") as out:
            json.dump(value_dict, out, indent=2, ensure_ascii=False)

# %%
def extract_values(entry):
    values = entry["values"]
    
    level_3_values = "\n".join(v["level_1_value"] for v in values.get("level_1_values", []))
    level_2_values = "\n".join(v["level_2_value"] for v in values.get("level_2_values", []))
    level_1_values = "\n".join(v["level_3_value"] for v in values.get("level_3_values", []))
    
    return level_1_values, level_2_values, level_3_values

with open("cleaned_misogyny_problem_definitions.json", "r") as f:
    PROBLEM_DEFINITIONS = json.load(f)
frame_problems_dict = {}

for f in read_jsonl('frame_problem_info.jsonl'):
    frame_problems_dict[f['id']] = {
        "frame": f['frame'],
        "problems": f['problems']
    }

# %%
for f in sorted(os.listdir('final_frames')):
    folder_path = os.path.join('final_frames', f)
    
    # Check if it's a folder and contains 'values_contra.jsonl'
    if os.path.isdir(folder_path) and os.path.exists(os.path.join(folder_path, 'values_contra.jsonl')):
        continue 
    val_file=os.path.join('final_frames',f,'value_dict.json')
    
    with open(val_file, "r", encoding="utf-8") as e:
        value_dict = json.load(e)

    ffilename = os.path.join('final_frames', f, 'frames.jsonl')

    problem_values=[]
    for frame in read_jsonl(ffilename):
        idf= frame['id']
        problems = frame_problems_dict[idf]['problems']
        problems_definitions_str = "\n".join(
    f"{problem.replace('_', ' ').title()}: {PROBLEM_DEFINITIONS.get(problem, 'No definition available')}"
    for problem in problems
        
)
        print(problems_definitions_str)
        value_entry = value_dict.get(idf)
        level_1_values, level_2_values, level_3_values = extract_values(value_entry)
        print(level_1_values)
        response = generate_response(config, frame['frame'], problems_definitions_str, level_1_values, level_2_values, level_3_values)
        if response is None:
            print(f"Intial response was None, skipping this frame {idf}.")
            continue
        
        history = History()

        while True:
            feedback = generate_feedback(feedback_config, response, frame)
            if stop_condition(feedback, history):
                print(f"Stopping condition met for frame {idf}.")
                break
            if feedback is None:
                print(f"Feedback response was None, skipping this frame {idf}.")
                break
            refined_response = refine_response(refine_config, feedback, response, frame)
            if refined_response is None:
                print(f"Refined response was None, skipping this frame {idf}.")
                break
            history.add(response, feedback.feedback, refined_response)
            response = refined_response
        problem_values.append({
            "id": idf,
            "frame": frame,
            "response": response.model_dump(),
            "history": [step.model_dump() for step in history.history],
        })
    write_jsonl(os.path.join('final_frames', f, 'values_contra.jsonl'), problem_values) 
    print(f"Done {f} problem")
# Out:
# Promoting Rape Culture: Perpetuation of attitudes, norms, and practices that normalize, trivialize, or excuse sexual violence and harassment
# Be respecting traditions
# Be behaving properly
# Have the right to command
# Stopping condition met for frame f1287.
# Promoting Rape Culture: Perpetuation of attitudes, norms, and practices that normalize, trivialize, or excuse sexual violence and harassment
# Have the right to command
# Be daring
# Have pleasure
# Stopping condition met for frame f354.
# Promoting Rape Culture: Perpetuation of attitudes, norms, and practices that normalize, trivialize, or excuse sexual violence and harassment
# Be respecting traditions
# Have the right to command
# Stopping condition met for frame f5388.
# Objectification: The action of degrading women to the status of a mere object
# Promoting Rape Culture: Perpetuation of attitudes, norms, and practices that normalize, trivialize, or excuse sexual violence and harassment
# Have pleasure
# Stopping condition met for frame f5387.
# Promoting Rape Culture: Perpetuation of attitudes, norms, and practices that normalize, trivialize, or excuse sexual violence and harassment
# Have an exciting life
# Have pleasure
# Have the right to command
# Stopping condition met for frame f2837.
# Promoting Rape Culture: Perpetuation of attitudes, norms, and practices that normalize, trivialize, or excuse sexual violence and harassment
# Have freedom of action
# Have the right to command
# Stopping condition met for frame f209.
# Promoting Rape Culture: Perpetuation of attitudes, norms, and practices that normalize, trivialize, or excuse sexual violence and harassment
# Have the right to command
# Stopping condition met for frame f4015.
# Promoting Rape Culture: Perpetuation of attitudes, norms, and practices that normalize, trivialize, or excuse sexual violence and harassment
# Trivializing Consent: Downplaying or minimizing the importance of obtaining and respecting consent in sexual or interpersonal situations
# Be just
# Have a stable society
# Have the right to command
# Stopping condition met for frame f880.
# Promoting Rape Culture: Perpetuation of attitudes, norms, and practices that normalize, trivialize, or excuse sexual violence and harassment
# Keep safe from harm
# Maintain personal safety
# Stopping condition met for frame f3331.
# Promoting Rape Culture: Perpetuation of attitudes, norms, and practices that normalize, trivialize, or excuse sexual violence and harassment
# Trivializing Consent: Downplaying or minimizing the importance of obtaining and respecting consent in sexual or interpersonal situations
# Have freedom of action
# Have pleasure
# Stopping condition met for frame f4748.
# Promoting Rape Culture: Perpetuation of attitudes, norms, and practices that normalize, trivialize, or excuse sexual violence and harassment
# Have influence
# Have the right to command
# Stopping condition met for frame f5369.
# Promoting Rape Culture: Perpetuation of attitudes, norms, and practices that normalize, trivialize, or excuse sexual violence and harassment
# Have influence
# Be just
# Have equality
# Be helpful
# Be polite
# Stopping condition met for frame f7777.
# Done promoting_rape_culture problem
# Promoting Self Harm: Actions, messages, or behaviors that encourage or pressure women to inflict harm upon themselves, either physically or psychologically
# Have the right to command
# Be respecting traditions
# Be compliant
# Have a stable society
# Stopping condition met for frame f2153.
# Promoting Self Harm: Actions, messages, or behaviors that encourage or pressure women to inflict harm upon themselves, either physically or psychologically
# Have pleasure
# Be respecting traditions
# Stopping condition met for frame f2704.
# Dismissing Women S Rights: Disregarding, minimizing, or invalidating the importance and validity of women's rights and issues related to gender equality
# Promoting Self Harm: Actions, messages, or behaviors that encourage or pressure women to inflict harm upon themselves, either physically or psychologically
# Be compliant
# Be respecting traditions
# Have a stable society
# Stopping condition met for frame f3676.
# Promoting Self Harm: Actions, messages, or behaviors that encourage or pressure women to inflict harm upon themselves, either physically or psychologically
# Have a good reputation
# Stopping condition met for frame f5238.
# Promoting Self Harm: Actions, messages, or behaviors that encourage or pressure women to inflict harm upon themselves, either physically or psychologically
# Have freedom of action
# Be daring
# Have pleasure
# Stopping condition met for frame f5577.
# Promoting Self Harm: Actions, messages, or behaviors that encourage or pressure women to inflict harm upon themselves, either physically or psychologically
# Have the right to command
# Stopping condition met for frame f6054.
# Done promoting_self_harm problem
# Racism: Prejudice or antagonism against a woman on the basis of her membership in a particular racial or ethnic group
# Have the right to command
# Stopping condition met for frame f3706.
# Racism: Prejudice or antagonism against a woman on the basis of her membership in a particular racial or ethnic group
# Have the right to command
# Be respecting traditions
# Be compliant
# Have a stable society
# Stopping condition met for frame f3817.
# Racism: Prejudice or antagonism against a woman on the basis of her membership in a particular racial or ethnic group
# Have a safe country
# Have a stable society
# Be respecting traditions
# Have a good reputation
# Be behaving properly
# Stopping condition met for frame f3666.
# Racism: Prejudice or antagonism against a woman on the basis of her membership in a particular racial or ethnic group
# Have the right to command
# Stopping condition met for frame f1699.
# Racism: Prejudice or antagonism against a woman on the basis of her membership in a particular racial or ethnic group
# Be respecting traditions
# Be polite
# Be honoring elders
# Stopping condition met for frame f2969.
# Racism: Prejudice or antagonism against a woman on the basis of her membership in a particular racial or ethnic group
# Stereotyping: Application of broad, oversimplified, and often negative generalizations about women based on their gender
# Be polite
# Be behaving properly
# Have a stable society
# Have a good reputation
# Stopping condition met for frame f3649.
# Racism: Prejudice or antagonism against a woman on the basis of her membership in a particular racial or ethnic group
# Have a good reputation
# Be behaving properly
# Have influence
# Stopping condition met for frame f3929.
# Intersectional Prejudice: Prejudice based on the simultaneous overlap of multiple social identities, like race, gender, class, or sexual orientation, where the discrimination stemming from each identity combines to create a unique and often more severe form of prejudice against a woman
# Racism: Prejudice or antagonism against a woman on the basis of her membership in a particular racial or ethnic group
# Be respecting traditions
# Stopping condition met for frame f5193.
# Racism: Prejudice or antagonism against a woman on the basis of her membership in a particular racial or ethnic group
# Be respecting traditions
# Be behaving properly
# Have a stable society
# Stopping condition met for frame f6085.
# Intersectional Prejudice: Prejudice based on the simultaneous overlap of multiple social identities, like race, gender, class, or sexual orientation, where the discrimination stemming from each identity combines to create a unique and often more severe form of prejudice against a woman
# Racism: Prejudice or antagonism against a woman on the basis of her membership in a particular racial or ethnic group
# Be respecting traditions
# Be behaving properly
# Have the right to command
# Stopping condition met for frame f6336.
# Racism: Prejudice or antagonism against a woman on the basis of her membership in a particular racial or ethnic group
# Be compliant
# Have influence
# Be respecting traditions
# Stopping condition met for frame f6359.
# Racism: Prejudice or antagonism against a woman on the basis of her membership in a particular racial or ethnic group
# Have social recognition
# Be compliant
# Stopping condition met for frame f7569.
# Done racism problem
# Reductionism: Oversimplification of women's identities, experiences, or roles by reducing them to narrow or stereotypical aspects [Note: This is also listed under 2.4]
# Have social recognition
# Stopping condition met for frame f2219.
# Reductionism: Oversimplification of women's identities, experiences, or roles by reducing them to narrow or stereotypical aspects [Note: This is also listed under 2.4]
# Have social recognition
# Stopping condition met for frame f7238.
# Objectification: The action of degrading women to the status of a mere object
# Reductionism: Oversimplification of women's identities, experiences, or roles by reducing them to narrow or stereotypical aspects [Note: This is also listed under 2.4]
# Be respecting traditions
# Have the right to command
# Stopping condition met for frame f685.
# Reductionism: Oversimplification of women's identities, experiences, or roles by reducing them to narrow or stereotypical aspects [Note: This is also listed under 2.4]
# Be respecting traditions
# Have a stable society
# Have the right to command
# Stopping condition met for frame f5964.
# Reductionism: Oversimplification of women's identities, experiences, or roles by reducing them to narrow or stereotypical aspects [Note: This is also listed under 2.4]
# Have freedom of action
# Be daring
# Stopping condition met for frame f4704.
# Reductionism: Oversimplification of women's identities, experiences, or roles by reducing them to narrow or stereotypical aspects [Note: This is also listed under 2.4]
# Be respecting traditions
# Have a good reputation
# Stopping condition met for frame f5131.
# Reductionism: Oversimplification of women's identities, experiences, or roles by reducing them to narrow or stereotypical aspects [Note: This is also listed under 2.4]
# Have pleasure
# Have the right to command
# Stopping condition met for frame f562.
# Reductionism: Oversimplification of women's identities, experiences, or roles by reducing them to narrow or stereotypical aspects [Note: This is also listed under 2.4]
# Be respecting traditions
# Have a stable society
# Have a world at peace
# Stopping condition met for frame f7457.
# Demonization: Portraying women as inherently evil, dangerous, or morally corrupt
# Reductionism: Oversimplification of women's identities, experiences, or roles by reducing them to narrow or stereotypical aspects [Note: This is also listed under 2.4]
# Have social recognition
# Stopping condition met for frame f3603.
# Reductionism: Oversimplification of women's identities, experiences, or roles by reducing them to narrow or stereotypical aspects [Note: This is also listed under 2.4]
# Ridicule: Mocking, belittling, or making fun of women in a way that undermines their dignity, worth, or autonomy [Note: This is also listed under 4.2]
# Be polite
# Be behaving properly
# Be respecting traditions
# Stopping condition met for frame f3755.
# Objectification: The action of degrading women to the status of a mere object
# Reductionism: Oversimplification of women's identities, experiences, or roles by reducing them to narrow or stereotypical aspects [Note: This is also listed under 2.4]
# Be respecting traditions
# Be compliant
# Have the right to command
# Stopping condition met for frame f5718.
# Reductionism: Oversimplification of women's identities, experiences, or roles by reducing them to narrow or stereotypical aspects [Note: This is also listed under 2.4]
# Be loving
# Be polite
# Stopping condition met for frame f1171.
# Reductionism: Oversimplification of women's identities, experiences, or roles by reducing them to narrow or stereotypical aspects [Note: This is also listed under 2.4]
# Stigmatization: Regarding women as worthy of disgrace or great disapproval
# Be respecting traditions
# Have a sense of belonging
# Stopping condition met for frame f1014.
# Reductionism: Oversimplification of women's identities, experiences, or roles by reducing them to narrow or stereotypical aspects [Note: This is also listed under 2.4]
# Have influence
# Stopping condition met for frame f2466.
# Reductionism: Oversimplification of women's identities, experiences, or roles by reducing them to narrow or stereotypical aspects [Note: This is also listed under 2.4]
# Be neat and tidy
# Stopping condition met for frame f6923.
# Reductionism: Oversimplification of women's identities, experiences, or roles by reducing them to narrow or stereotypical aspects [Note: This is also listed under 2.4]
# Be respecting traditions
# Be polite
# Stopping condition met for frame f2824.
# Reductionism: Oversimplification of women's identities, experiences, or roles by reducing them to narrow or stereotypical aspects [Note: This is also listed under 2.4]
# Be choosing own goals
# Have freedom of action
# Be ambitious
# Have success
# Have influence
# Have the right to command
# Stopping condition met for frame f4677.
# Reductionism: Oversimplification of women's identities, experiences, or roles by reducing them to narrow or stereotypical aspects [Note: This is also listed under 2.4]
# Have wealth
# Have pleasure
# Stopping condition met for frame f2157.
# Reductionism: Oversimplification of women's identities, experiences, or roles by reducing them to narrow or stereotypical aspects [Note: This is also listed under 2.4]
# Be respecting traditions
# Be behaving properly
# Stopping condition met for frame f4291.
# Reductionism: Oversimplification of women's identities, experiences, or roles by reducing them to narrow or stereotypical aspects [Note: This is also listed under 2.4]
# Stereotyping: Application of broad, oversimplified, and often negative generalizations about women based on their gender
# Be intellectual
# Stopping condition met for frame f1033.
# Reductionism: Oversimplification of women's identities, experiences, or roles by reducing them to narrow or stereotypical aspects [Note: This is also listed under 2.4]
# Have wealth
# Have a comfortable life
# Stopping condition met for frame f3932.
# Reductionism: Oversimplification of women's identities, experiences, or roles by reducing them to narrow or stereotypical aspects [Note: This is also listed under 2.4]
# Have wealth
# Stopping condition met for frame f62.
# Reductionism: Oversimplification of women's identities, experiences, or roles by reducing them to narrow or stereotypical aspects [Note: This is also listed under 2.4]
# Be neat and tidy
# Have pleasure
# Stopping condition met for frame f3355.
# Reductionism: Oversimplification of women's identities, experiences, or roles by reducing them to narrow or stereotypical aspects [Note: This is also listed under 2.4]
# Be polite
# Have a good reputation
# Stopping condition met for frame f956.
# Reductionism: Oversimplification of women's identities, experiences, or roles by reducing them to narrow or stereotypical aspects [Note: This is also listed under 2.4]
# Be self-disciplined
# Be honest
# Stopping condition met for frame f1932.
# Reductionism: Oversimplification of women's identities, experiences, or roles by reducing them to narrow or stereotypical aspects [Note: This is also listed under 2.4]
# Be logical
# Have an objective view
# Stopping condition met for frame f2028.
# Reductionism: Oversimplification of women's identities, experiences, or roles by reducing them to narrow or stereotypical aspects [Note: This is also listed under 2.4]
# Be ambitious
# Have success
# Be capable
# Be intellectual
# Have a social recognition
# Have a good reputation
# Stopping condition met for frame f2037.
# Reductionism: Oversimplification of women's identities, experiences, or roles by reducing them to narrow or stereotypical aspects [Note: This is also listed under 2.4]
# Have the right to command
# Be respecting traditions
# Stopping condition met for frame f3324.
# Reductionism: Oversimplification of women's identities, experiences, or roles by reducing them to narrow or stereotypical aspects [Note: This is also listed under 2.4]
# Be compliant
# Have influence
# Stopping condition met for frame f3327.
# Biased Judgement: Biased evaluation or criticism of women based on sexist attitudes and stereotypes
# Reductionism: Oversimplification of women's identities, experiences, or roles by reducing them to narrow or stereotypical aspects [Note: This is also listed under 2.4]
# Be self-disciplined
# Be behaving properly
# Be compliant
# Stopping condition met for frame f3968.
# Reductionism: Oversimplification of women's identities, experiences, or roles by reducing them to narrow or stereotypical aspects [Note: This is also listed under 2.4]
# Have no debts
# Be self-disciplined
# Be ambitious
# Stopping condition met for frame f6183.
# Reductionism: Oversimplification of women's identities, experiences, or roles by reducing them to narrow or stereotypical aspects [Note: This is also listed under 2.4]
# Have success
# Have a good reputation
# Be compliant
# Stopping condition met for frame f6486.
# Reductionism: Oversimplification of women's identities, experiences, or roles by reducing them to narrow or stereotypical aspects [Note: This is also listed under 2.4]
# Have good health
# Be compliant
# Be self-disciplined
# Stopping condition met for frame f6724.
# Reductionism: Oversimplification of women's identities, experiences, or roles by reducing them to narrow or stereotypical aspects [Note: This is also listed under 2.4]
# Be compliant
# Be respecting traditions
# Stopping condition met for frame f7479.
# Reductionism: Oversimplification of women's identities, experiences, or roles by reducing them to narrow or stereotypical aspects [Note: This is also listed under 2.4]
# Have influence
# Have pleasure
# Stopping condition met for frame f7488.
# Done reductionism problem
# Reverse Sexism: Sexism directed toward men or boys, often as a reaction to the discrimination and inequalities faced by women
# Be respecting traditions
# Have a stable society
# Have the right to command
# Stopping condition met for frame f2175.
# Reverse Sexism: Sexism directed toward men or boys, often as a reaction to the discrimination and inequalities faced by women
# Be respecting traditions
# Stopping condition met for frame f7278.
# Reverse Sexism: Sexism directed toward men or boys, often as a reaction to the discrimination and inequalities faced by women
# Have influence
# Have a stable society
# Be respecting traditions
# Stopping condition met for frame f381.
# Reverse Sexism: Sexism directed toward men or boys, often as a reaction to the discrimination and inequalities faced by women
# Have equality
# Be just
# Have an objective view
# Stopping condition met for frame f82.
# Reverse Sexism: Sexism directed toward men or boys, often as a reaction to the discrimination and inequalities faced by women
# Be just
# Have an objective view
# Be broadminded
# Be honest
# Stopping condition met for frame f925.
# Reverse Sexism: Sexism directed toward men or boys, often as a reaction to the discrimination and inequalities faced by women
# Attributing inherent moral inferiority/evilness to the group
# Stopping condition met for frame f989.
# Reverse Sexism: Sexism directed toward men or boys, often as a reaction to the discrimination and inequalities faced by women
# Have wealth
# Stopping condition met for frame f1285.
# Reverse Sexism: Sexism directed toward men or boys, often as a reaction to the discrimination and inequalities faced by women
# Be capable
# Have success
# Stopping condition met for frame f2203.
# Reverse Sexism: Sexism directed toward men or boys, often as a reaction to the discrimination and inequalities faced by women
# Be polite
# Be compliant
# Have a good reputation
# Be loving
# Be responsible
# Stopping condition met for frame f2506.
# Reverse Sexism: Sexism directed toward men or boys, often as a reaction to the discrimination and inequalities faced by women
# Stereotyping: Application of broad, oversimplified, and often negative generalizations about women based on their gender
# Be polite
# Stopping condition met for frame f4370.
# Reverse Sexism: Sexism directed toward men or boys, often as a reaction to the discrimination and inequalities faced by women
# Have a stable society
# Have good health
# Stopping condition met for frame f5597.
# Reverse Sexism: Sexism directed toward men or boys, often as a reaction to the discrimination and inequalities faced by women
# Be capable
# Have the right to command
# Have a stable society
# Be just
# Stopping condition met for frame f6068.
# Reverse Sexism: Sexism directed toward men or boys, often as a reaction to the discrimination and inequalities faced by women
# Have influence
# Have a stable society
# Be polite
# Have a good reputation
# Stopping condition met for frame f6265.
# Reverse Sexism: Sexism directed toward men or boys, often as a reaction to the discrimination and inequalities faced by women
# Be respecting traditions
# Have social recognition
# Stopping condition met for frame f7659.
# Reverse Sexism: Sexism directed toward men or boys, often as a reaction to the discrimination and inequalities faced by women
# Be capable
# Be courageous
# Have influence
# Have the right to command
# Have a good reputation
# Stopping condition met for frame f7974.
# Done reverse_sexism problem
# Ridicule: Mocking, belittling, or making fun of women in a way that undermines their dignity, worth, or autonomy [Note: This is also listed under 4.2]
# Have social recognition
# Be behaving properly
# Be respecting traditions
# Stopping condition met for frame f932.
# Ridicule: Mocking, belittling, or making fun of women in a way that undermines their dignity, worth, or autonomy [Note: This is also listed under 4.2]
# Be respecting traditions
# Be behaving properly
# Have a good reputation
# Stopping condition met for frame f3847.
# Derogatory Labeling: Use of negative, demeaning, or contemptuous terms to describe or refer to women [Note: This is also listed under 4.1]
# Ridicule: Mocking, belittling, or making fun of women in a way that undermines their dignity, worth, or autonomy [Note: This is also listed under 4.2]
# Be responsible
# Stopping condition met for frame f701.
# Ridicule: Mocking, belittling, or making fun of women in a way that undermines their dignity, worth, or autonomy [Note: This is also listed under 4.2]
# Be behaving properly
# Have a good reputation
# Stopping condition met for frame f4535.
# Ridicule: Mocking, belittling, or making fun of women in a way that undermines their dignity, worth, or autonomy [Note: This is also listed under 4.2]
# Be humble
# Stopping condition met for frame f7536.
# Ridicule: Mocking, belittling, or making fun of women in a way that undermines their dignity, worth, or autonomy [Note: This is also listed under 4.2]
# Be respecting traditions
# Be compliant
# Be behaving properly
# Stopping condition met for frame f154.
# Ridicule: Mocking, belittling, or making fun of women in a way that undermines their dignity, worth, or autonomy [Note: This is also listed under 4.2]
# Transphobia: Dislike of or strong prejudice against transgender people
# Be behaving properly
# Stopping condition met for frame f1632.
# Ridicule: Mocking, belittling, or making fun of women in a way that undermines their dignity, worth, or autonomy [Note: This is also listed under 4.2]
# Be respecting traditions
# Be compliant
# Stopping condition met for frame f3958.
# Ridicule: Mocking, belittling, or making fun of women in a way that undermines their dignity, worth, or autonomy [Note: This is also listed under 4.2]
# Be independent
# Be polite
# Stopping condition met for frame f5638.
# Reductionism: Oversimplification of women's identities, experiences, or roles by reducing them to narrow or stereotypical aspects [Note: This is also listed under 2.4]
# Ridicule: Mocking, belittling, or making fun of women in a way that undermines their dignity, worth, or autonomy [Note: This is also listed under 4.2]
# Have the right to command
# Be respecting traditions
# Have a comfortable life
# Stopping condition met for frame f3755.
# Ridicule: Mocking, belittling, or making fun of women in a way that undermines their dignity, worth, or autonomy [Note: This is also listed under 4.2]
# Have pleasure
# Be respecting traditions
# Stopping condition met for frame f2374.
# Ridicule: Mocking, belittling, or making fun of women in a way that undermines their dignity, worth, or autonomy [Note: This is also listed under 4.2]
# Have influence
# Have social recognition
# Stopping condition met for frame f7214.
# Ridicule: Mocking, belittling, or making fun of women in a way that undermines their dignity, worth, or autonomy [Note: This is also listed under 4.2]
# Be creative
# Have freedom of thought
# Have an exciting life
# Have pleasure
# Have influence
# Be respecting traditions
# Stopping condition met for frame f7625.
# Ridicule: Mocking, belittling, or making fun of women in a way that undermines their dignity, worth, or autonomy [Note: This is also listed under 4.2]
# Have the right to command
# Be respecting traditions
# Stopping condition met for frame f5954.
# Ridicule: Mocking, belittling, or making fun of women in a way that undermines their dignity, worth, or autonomy [Note: This is also listed under 4.2]
# Stereotyping: Application of broad, oversimplified, and often negative generalizations about women based on their gender
# Be capable
# Stopping condition met for frame f1541.
# Ridicule: Mocking, belittling, or making fun of women in a way that undermines their dignity, worth, or autonomy [Note: This is also listed under 4.2]
# Be respecting traditions
# Have a good reputation
# Stopping condition met for frame f7216.
# Dismissiveness: Having or showing a disdainful attitude toward women regarded as unworthy of serious attention
# Ridicule: Mocking, belittling, or making fun of women in a way that undermines their dignity, worth, or autonomy [Note: This is also listed under 4.2]
# Have the right to command
# Stopping condition met for frame f6854.
# Ridicule: Mocking, belittling, or making fun of women in a way that undermines their dignity, worth, or autonomy [Note: This is also listed under 4.2]
# Be respecting traditions
# Have the right to command
# Have influence
# Have a good reputation
# Have social recognition
# Stopping condition met for frame f4606.
# Double Standards: Practice of applying different sets of rules, expectations, or judgments to individuals based on their gender, with men and women often being treated unequally
# Ridicule: Mocking, belittling, or making fun of women in a way that undermines their dignity, worth, or autonomy [Note: This is also listed under 4.2]
# Be behaving properly
# Be respecting traditions
# Stopping condition met for frame f103.
# Ridicule: Mocking, belittling, or making fun of women in a way that undermines their dignity, worth, or autonomy [Note: This is also listed under 4.2]
# Have social recognition
# Be respecting traditions
# Stopping condition met for frame f6680.
# Ridicule: Mocking, belittling, or making fun of women in a way that undermines their dignity, worth, or autonomy [Note: This is also listed under 4.2]
# Have good health
# Be self‐disciplined
# Stopping condition met for frame f1854.
# Ridicule: Mocking, belittling, or making fun of women in a way that undermines their dignity, worth, or autonomy [Note: This is also listed under 4.2]
# Have the right to command
# Stopping condition met for frame f7269.
# Ridicule: Mocking, belittling, or making fun of women in a way that undermines their dignity, worth, or autonomy [Note: This is also listed under 4.2]
# Have a stable society
# Be compliant
# Have the right to command
# Stopping condition met for frame f2793.
# Ridicule: Mocking, belittling, or making fun of women in a way that undermines their dignity, worth, or autonomy [Note: This is also listed under 4.2]
# Have social recognition
# Stopping condition met for frame f2956.
# Biased Judgement: Biased evaluation or criticism of women based on sexist attitudes and stereotypes
# Ridicule: Mocking, belittling, or making fun of women in a way that undermines their dignity, worth, or autonomy [Note: This is also listed under 4.2]
# Be respecting traditions
# Be polite
# Be compliant
# Have a comfortable life
# Have a good reputation
# Stopping condition met for frame f5481.
# Ridicule: Mocking, belittling, or making fun of women in a way that undermines their dignity, worth, or autonomy [Note: This is also listed under 4.2]
# Have influence
# Be respecting traditions
# Stopping condition met for frame f5849.
# Derogatory Labeling: Use of negative, demeaning, or contemptuous terms to describe or refer to women [Note: This is also listed under 4.1]
# Ridicule: Mocking, belittling, or making fun of women in a way that undermines their dignity, worth, or autonomy [Note: This is also listed under 4.2]
# Be helpful
# Be honest
# Have social recognition
# Have pleasure
# Stopping condition met for frame f3522.
# Dismissiveness: Having or showing a disdainful attitude toward women regarded as unworthy of serious attention
# Ridicule: Mocking, belittling, or making fun of women in a way that undermines their dignity, worth, or autonomy [Note: This is also listed under 4.2]
# Have social recognition
# Stopping condition met for frame f522.
# Misrepresentation: The distortion or incorrect portrayal of women and their experiences, often driven by sexist biases and stereotypes
# Ridicule: Mocking, belittling, or making fun of women in a way that undermines their dignity, worth, or autonomy [Note: This is also listed under 4.2]
# Be capable
# Have the right to command
# Be respecting traditions
# Stopping condition met for frame f7421.
# Ageism: Prejudice against women based on their age, often rooted in sexist beliefs that devalue women as they grow older
# Ridicule: Mocking, belittling, or making fun of women in a way that undermines their dignity, worth, or autonomy [Note: This is also listed under 4.2]
# Be respecting traditions
# Be polite
# Have a good reputation
# Stopping condition met for frame f934.
# Ridicule: Mocking, belittling, or making fun of women in a way that undermines their dignity, worth, or autonomy [Note: This is also listed under 4.2]
# Stereotyping: Application of broad, oversimplified, and often negative generalizations about women based on their gender
# Be independent
# Have freedom of action
# Be respecting traditions
# Stopping condition met for frame f1222.
# Ridicule: Mocking, belittling, or making fun of women in a way that undermines their dignity, worth, or autonomy [Note: This is also listed under 4.2]
# Be neat and tidy
# Have good health
# Stopping condition met for frame f1283.
# Ridicule: Mocking, belittling, or making fun of women in a way that undermines their dignity, worth, or autonomy [Note: This is also listed under 4.2]
# Be respecting traditions
# Be behaving properly
# Have a sense of belonging
# Stopping condition met for frame f1833.
# Ridicule: Mocking, belittling, or making fun of women in a way that undermines their dignity, worth, or autonomy [Note: This is also listed under 4.2]
# Have the right to command
# Stopping condition met for frame f2112.
# Ridicule: Mocking, belittling, or making fun of women in a way that undermines their dignity, worth, or autonomy [Note: This is also listed under 4.2]
# Have a good reputation
# Stopping condition met for frame f2322.
# Ridicule: Mocking, belittling, or making fun of women in a way that undermines their dignity, worth, or autonomy [Note: This is also listed under 4.2]
# Be neat and tidy
# Be polite
# Be respecting traditions
# Be behaving properly
# Stopping condition met for frame f2613.
# Homophobia: Dislike of or prejudice against lesbians
# Ridicule: Mocking, belittling, or making fun of women in a way that undermines their dignity, worth, or autonomy [Note: This is also listed under 4.2]
# Be respecting traditions
# Be behaving properly
# Stopping condition met for frame f3922.
# Ridicule: Mocking, belittling, or making fun of women in a way that undermines their dignity, worth, or autonomy [Note: This is also listed under 4.2]
# Be self-disciplined
# Be respecting traditions
# Have a stable society
# Have the right to command
# Stopping condition met for frame f4883.
# Ridicule: Mocking, belittling, or making fun of women in a way that undermines their dignity, worth, or autonomy [Note: This is also listed under 4.2]
# Have the right to command
# Be respecting traditions
# Stopping condition met for frame f5499.
# Ridicule: Mocking, belittling, or making fun of women in a way that undermines their dignity, worth, or autonomy [Note: This is also listed under 4.2]
# Have influence
# Stopping condition met for frame f5924.
# Ridicule: Mocking, belittling, or making fun of women in a way that undermines their dignity, worth, or autonomy [Note: This is also listed under 4.2]
# Stereotyping: Application of broad, oversimplified, and often negative generalizations about women based on their gender
# Be capable
# Be intellectual
# Have the right to command
# Stopping condition met for frame f6319.
# Double Standards: Practice of applying different sets of rules, expectations, or judgments to individuals based on their gender, with men and women often being treated unequally
# Policing Women S Bodies: Practices and mechanisms through which societal, cultural, or institutional forces regulate, control, and scrutinize women's bodies and behaviors
# Ridicule: Mocking, belittling, or making fun of women in a way that undermines their dignity, worth, or autonomy [Note: This is also listed under 4.2]
# Be behaving properly
# Stopping condition met for frame f6400.
# Ridicule: Mocking, belittling, or making fun of women in a way that undermines their dignity, worth, or autonomy [Note: This is also listed under 4.2]
# Have a good reputation
# Be behaving properly
# Stopping condition met for frame f6553.
# Ridicule: Mocking, belittling, or making fun of women in a way that undermines their dignity, worth, or autonomy [Note: This is also listed under 4.2]
# Have influence
# Have the right to command
# Have social recognition
# Be behaving properly
# Stopping condition met for frame f7515.
# Done ridicule problem
# Scapegoating: Unfairly blaming women for problems, failures, or negative events, even though they are not responsible
# Have a social recognition
# Have a good reputation
# Stopping condition met for frame f7717.
# Scapegoating: Unfairly blaming women for problems, failures, or negative events, even though they are not responsible
# Be respecting traditions
# Be behaving properly
# Be polite
# Have a good reputation
# Stopping condition met for frame f6040.
# Scapegoating: Unfairly blaming women for problems, failures, or negative events, even though they are not responsible
# Have wealth
# Have no debts
# Be self-disciplined
# Stopping condition met for frame f6109.
# Scapegoating: Unfairly blaming women for problems, failures, or negative events, even though they are not responsible
# Have the right to command
# Be polite
# Stopping condition met for frame f6121.
# Scapegoating: Unfairly blaming women for problems, failures, or negative events, even though they are not responsible
# Have social recognition
# Stopping condition met for frame f7286.
# Scapegoating: Unfairly blaming women for problems, failures, or negative events, even though they are not responsible
# Have freedom of action
# Have the right to command
# Have a stable society
# Have an objective view
# Stopping condition met for frame f2401.
# Scapegoating: Unfairly blaming women for problems, failures, or negative events, even though they are not responsible
# Be respecting traditions
# Be compliant
# Stopping condition met for frame f2636.
# Scapegoating: Unfairly blaming women for problems, failures, or negative events, even though they are not responsible
# Honor traditional gender roles
# Be polite
# Assert authority
# Stopping condition met for frame f5841.
# Scapegoating: Unfairly blaming women for problems, failures, or negative events, even though they are not responsible
# Be respecting traditions
# Be behaving properly
# Have a stable society
# Have a good reputation
# Stopping condition met for frame f4226.
# Scapegoating: Unfairly blaming women for problems, failures, or negative events, even though they are not responsible
# Undermining Women S Rights Movements: Actions or attitudes that diminish, obstruct, or discredit the efforts and goals of movements advocating for gender equality and women's rights
# Have wealth
# Be respecting traditions
# Stopping condition met for frame f5742.
# Scapegoating: Unfairly blaming women for problems, failures, or negative events, even though they are not responsible
# Have influence
# Stopping condition met for frame f348.
# Scapegoating: Unfairly blaming women for problems, failures, or negative events, even though they are not responsible
# Have the right to command
# Have a stable society
# Be respecting traditions
# Stopping condition met for frame f6285.
# Scapegoating: Unfairly blaming women for problems, failures, or negative events, even though they are not responsible
# Have pleasure
# Stopping condition met for frame f3809.
# Scapegoating: Unfairly blaming women for problems, failures, or negative events, even though they are not responsible
# Be respecting traditions
# Be polite
# Have the right to command
# Have a stable society
# Stopping condition met for frame f5288.
# Scapegoating: Unfairly blaming women for problems, failures, or negative events, even though they are not responsible
# Be capable
# Have success
# Have the right to command
# Be respecting traditions
# Have a stable society
# Stopping condition met for frame f5722.
# Done scapegoating problem
# Sexist Pseudoscience: No definition available
# Be intellectual
# Have the right to command
# Stopping condition met for frame f3746.
# Sexist Pseudoscience: No definition available
# Have an objective view
# Be logical
# Stopping condition met for frame f1397.
# Sexist Pseudoscience: No definition available
# Be respecting traditions
# Stopping condition met for frame f7535.
# Done sexist_pseudoscience problem
# Sexual Entitlement: Belief that men's own sexual needs are more important than the feelings and rights of women
# Have pleasure
# Stopping condition met for frame f4419.
# Sexual Entitlement: Belief that men's own sexual needs are more important than the feelings and rights of women
# Have the right to command
# Be compliant
# Stopping condition met for frame f3541.
# Sexual Entitlement: Belief that men's own sexual needs are more important than the feelings and rights of women
# Have the right to command
# Be respecting traditions
# Stopping condition met for frame f859.
# Sexual Entitlement: Belief that men's own sexual needs are more important than the feelings and rights of women
# Be respecting traditions
# Be polite
# Have a stable society
# Have the right to command
# Stopping condition met for frame f3762.
# Sexual Entitlement: Belief that men's own sexual needs are more important than the feelings and rights of women
# Be respecting traditions
# Be polite
# Stopping condition met for frame f221.
# Sexual Entitlement: Belief that men's own sexual needs are more important than the feelings and rights of women
# Be respecting traditions
# Be behaving properly
# Stopping condition met for frame f3867.
# Sexual Entitlement: Belief that men's own sexual needs are more important than the feelings and rights of women
# Have an exciting life
# Have pleasure
# Be broadminded
# Stopping condition met for frame f5357.
# Objectification: The action of degrading women to the status of a mere object
# Sexual Entitlement: Belief that men's own sexual needs are more important than the feelings and rights of women
# Have the right to command
# Be respecting traditions
# Stopping condition met for frame f7947.
# Sexual Entitlement: Belief that men's own sexual needs are more important than the feelings and rights of women
# Have social recognition
# Have a sense of belonging
# Be compliant
# Stopping condition met for frame f5623.
# Sexual Entitlement: Belief that men's own sexual needs are more important than the feelings and rights of women
# Have the right to command
# Have influence
# Be respecting traditions
# Stopping condition met for frame f2295.
# Sexual Entitlement: Belief that men's own sexual needs are more important than the feelings and rights of women
# Be respecting traditions
# Be polite
# Have the right to command
# Have social recognition
# Stopping condition met for frame f3019.
# Sexual Entitlement: Belief that men's own sexual needs are more important than the feelings and rights of women
# Have pleasure
# Have influence
# Be behaving properly
# Stopping condition met for frame f5905.
# Sexual Entitlement: Belief that men's own sexual needs are more important than the feelings and rights of women
# Be compliant
# Have the right to command
# Be behaving properly
# Stopping condition met for frame f4506.
# Sexual Entitlement: Belief that men's own sexual needs are more important than the feelings and rights of women
# Be daring
# Have pleasure
# Stopping condition met for frame f147.
# Sexual Entitlement: Belief that men's own sexual needs are more important than the feelings and rights of women
# Sexual Innuendo: Subtly or indirectly suggesting sexual content, ideas, or connotations through language, gestures, or humor
# Respect traditions
# Be polite
# Have a good reputation
# Stopping condition met for frame f717.
# Sexual Entitlement: Belief that men's own sexual needs are more important than the feelings and rights of women
# Have the right to command
# Be compliant
# Stopping condition met for frame f4202.
# Objectification: The action of degrading women to the status of a mere object
# Sexual Entitlement: Belief that men's own sexual needs are more important than the feelings and rights of women
# Have the right to command
# Have pleasure
# Stopping condition met for frame f4461.
# Sexual Entitlement: Belief that men's own sexual needs are more important than the feelings and rights of women
# Have pleasure
# Stopping condition met for frame f5553.
# Sexual Entitlement: Belief that men's own sexual needs are more important than the feelings and rights of women
# Be respecting traditions
# Have the right to command
# Stopping condition met for frame f6267.
# Sexual Entitlement: Belief that men's own sexual needs are more important than the feelings and rights of women
# Have the right to command
# Be respecting traditions
# Be compliant
# Stopping condition met for frame f7086.
# Done sexual_entitlement problem
# Sexual Harassment: Unwelcome, inappropriate, or coercive behavior of a sexual nature that creates a hostile or intimidating environment
# Have freedom of action
# Have pleasure
# Have influence
# Stopping condition met for frame f4731.
# Sexual Harassment: Unwelcome, inappropriate, or coercive behavior of a sexual nature that creates a hostile or intimidating environment
# Have pleasure
# Have the right to command
# Stopping condition met for frame f7316.
# Sexual Harassment: Unwelcome, inappropriate, or coercive behavior of a sexual nature that creates a hostile or intimidating environment
# Have pleasure
# Have the right to command
# Be respecting traditions
# Stopping condition met for frame f3554.
# Sexual Harassment: Unwelcome, inappropriate, or coercive behavior of a sexual nature that creates a hostile or intimidating environment
# Have the right to command
# Have wealth
# Be respecting traditions
# Be compliant
# Stopping condition met for frame f5185.
# Sexual Harassment: Unwelcome, inappropriate, or coercive behavior of a sexual nature that creates a hostile or intimidating environment
# Have freedom of action
# Have pleasure
# Have influence
# Stopping condition met for frame f5635.
# Sexual Harassment: Unwelcome, inappropriate, or coercive behavior of a sexual nature that creates a hostile or intimidating environment
# Have pleasure
# Be daring
# Have freedom of action
# Have the right to command
# Stopping condition met for frame f6905.
# Done sexual_harassment problem
# Sexual Innuendo: Subtly or indirectly suggesting sexual content, ideas, or connotations through language, gestures, or humor
# Have pleasure
# Stopping condition met for frame f1204.
# Sexual Innuendo: Subtly or indirectly suggesting sexual content, ideas, or connotations through language, gestures, or humor
# Have social recognition
# Stopping condition met for frame f1466.
# Sexual Innuendo: Subtly or indirectly suggesting sexual content, ideas, or connotations through language, gestures, or humor
# Have pleasure
# Have an objective view
# Stopping condition met for frame f672.
# Sexual Innuendo: Subtly or indirectly suggesting sexual content, ideas, or connotations through language, gestures, or humor
# Be respecting traditions
# Be behaving properly
# Stopping condition met for frame f5289.
# Sexual Innuendo: Subtly or indirectly suggesting sexual content, ideas, or connotations through language, gestures, or humor
# Have the right to command
# Have pleasure
# Stopping condition met for frame f2215.
# Sexual Innuendo: Subtly or indirectly suggesting sexual content, ideas, or connotations through language, gestures, or humor
# Be respecting traditions
# Be honest
# Stopping condition met for frame f6762.
# Sexual Innuendo: Subtly or indirectly suggesting sexual content, ideas, or connotations through language, gestures, or humor
# Have pleasure
# Stopping condition met for frame f693.
# Intersectional Prejudice: Prejudice based on the simultaneous overlap of multiple social identities, like race, gender, class, or sexual orientation, where the discrimination stemming from each identity combines to create a unique and often more severe form of prejudice against a woman
# Sexual Innuendo: Subtly or indirectly suggesting sexual content, ideas, or connotations through language, gestures, or humor
# Have influence
# Have pleasure
# Stopping condition met for frame f3992.
# Sexual Entitlement: Belief that men's own sexual needs are more important than the feelings and rights of women
# Sexual Innuendo: Subtly or indirectly suggesting sexual content, ideas, or connotations through language, gestures, or humor
# Be behaving properly
# Be respecting traditions
# Have a good reputation
# Stopping condition met for frame f717.
# Sexual Innuendo: Subtly or indirectly suggesting sexual content, ideas, or connotations through language, gestures, or humor
# Have a stable society
# Have the right to command
# Be behaving properly
# Stopping condition met for frame f6433.
# Sexual Innuendo: Subtly or indirectly suggesting sexual content, ideas, or connotations through language, gestures, or humor
# Have pleasure
# Stopping condition met for frame f3000.
# Sexual Innuendo: Subtly or indirectly suggesting sexual content, ideas, or connotations through language, gestures, or humor
# Have the right to command
# Be respecting traditions
# Stopping condition met for frame f3901.
# Sexual Innuendo: Subtly or indirectly suggesting sexual content, ideas, or connotations through language, gestures, or humor
# Have pleasure
# Be daring
# Have influence
# Stopping condition met for frame f4881.
# Sexual Innuendo: Subtly or indirectly suggesting sexual content, ideas, or connotations through language, gestures, or humor
# Have freedom of thought
# Have freedom of action
# Be daring
# Have pleasure
# Stopping condition met for frame f5922.
# Objectification: The action of degrading women to the status of a mere object
# Sexual Innuendo: Subtly or indirectly suggesting sexual content, ideas, or connotations through language, gestures, or humor
# Have influence
# Stopping condition met for frame f6185.
# Sexual Innuendo: Subtly or indirectly suggesting sexual content, ideas, or connotations through language, gestures, or humor
# Have pleasure
# Stopping condition met for frame f6237.
# Sexual Innuendo: Subtly or indirectly suggesting sexual content, ideas, or connotations through language, gestures, or humor
# Have pleasure
# Stopping condition met for frame f6803.
# Sexual Innuendo: Subtly or indirectly suggesting sexual content, ideas, or connotations through language, gestures, or humor
# Have the right to command
# Be compliant
# Stopping condition met for frame f6942.
# Sexual Innuendo: Subtly or indirectly suggesting sexual content, ideas, or connotations through language, gestures, or humor
# Stereotyping: Application of broad, oversimplified, and often negative generalizations about women based on their gender
# Be respecting traditions
# Be behaving properly
# Stopping condition met for frame f7573.
# Objectification: The action of degrading women to the status of a mere object
# Sexual Innuendo: Subtly or indirectly suggesting sexual content, ideas, or connotations through language, gestures, or humor
# Have pleasure
# Have the right to command
# Stopping condition met for frame f7738.
# Done sexual_innuendo problem
# Sexualization: The act of viewing someone or something in a sexual way, or of emphasizing their sexual characteristics
# ...
# Be compliant
# Stopping condition met for frame f608.
# Deflection: Shifting responsibility or accountability for one's own actions, mistakes, or harmful behavior onto women
# Victim Blaming: Practice of attributing responsibility or fault to women for the violence, harassment, or discrimination they experience
# Be behaving properly
# Be respecting traditions
# Have a good reputation
# Stopping condition met for frame f480.
# Double Standards: Practice of applying different sets of rules, expectations, or judgments to individuals based on their gender, with men and women often being treated unequally
# Victim Blaming: Practice of attributing responsibility or fault to women for the violence, harassment, or discrimination they experience
# Be respecting traditions
# Be behaving properly
# Have a good reputation
# Have a stable society
# Stopping condition met for frame f1728.
# Trivializing Consent: Downplaying or minimizing the importance of obtaining and respecting consent in sexual or interpersonal situations
# Victim Blaming: Practice of attributing responsibility or fault to women for the violence, harassment, or discrimination they experience
# Have the right to command
# Stopping condition met for frame f2884.
# Endorsing Marital Rape: Acceptance, justification, or normalization of non-consensual sexual activity within marriage
# Victim Blaming: Practice of attributing responsibility or fault to women for the violence, harassment, or discrimination they experience
# Have the right to command
# Be respecting traditions
# Stopping condition met for frame f5420.
# Victim Blaming: Practice of attributing responsibility or fault to women for the violence, harassment, or discrimination they experience
# Be compliant
# Have a stable society
# Stopping condition met for frame f4852.
# Victim Blaming: Practice of attributing responsibility or fault to women for the violence, harassment, or discrimination they experience
# Be respecting traditions
# Be behaving properly
# Have the right to command
# Stopping condition met for frame f5835.
# Victim Blaming: Practice of attributing responsibility or fault to women for the violence, harassment, or discrimination they experience
# Be respecting traditions
# Be compliant
# Have a good reputation
# Stopping condition met for frame f7068.
# Done victim_blaming problem
# Violence: Physical, emotional, psychological, sexual, or economic harm directed at women or girls, driven by gender-based hatred, control, or discrimination
# Have the right to command
# Be respecting traditions
# Stopping condition met for frame f914.
# Violence: Physical, emotional, psychological, sexual, or economic harm directed at women or girls, driven by gender-based hatred, control, or discrimination
# Have the right to command
# Have pleasure
# Stopping condition met for frame f2055.
# Violence: Physical, emotional, psychological, sexual, or economic harm directed at women or girls, driven by gender-based hatred, control, or discrimination
# Have the right to command
# Be respecting traditions
# Stopping condition met for frame f1360.
# Violence: Physical, emotional, psychological, sexual, or economic harm directed at women or girls, driven by gender-based hatred, control, or discrimination
# Have the right to command
# Be respecting traditions
# Have a stable society
# Stopping condition met for frame f1078.
# Violence: Physical, emotional, psychological, sexual, or economic harm directed at women or girls, driven by gender-based hatred, control, or discrimination
# Have the right to command
# Be respecting traditions
# Have a stable society
# Stopping condition met for frame f861.
# Violence: Physical, emotional, psychological, sexual, or economic harm directed at women or girls, driven by gender-based hatred, control, or discrimination
# Have pleasure
# Have the right to command
# Stopping condition met for frame f314.
# Disposability: Perception or treatment of women as easily replaceable or expendable, reducing their value to a narrow, often utilitarian purpose
# Violence: Physical, emotional, psychological, sexual, or economic harm directed at women or girls, driven by gender-based hatred, control, or discrimination
# Have the right to command
# Stopping condition met for frame f6751.
# Violence: Physical, emotional, psychological, sexual, or economic harm directed at women or girls, driven by gender-based hatred, control, or discrimination
# Have the right to command
# Be respecting traditions
# Be compliant
# Stopping condition met for frame f1470.
# Violence: Physical, emotional, psychological, sexual, or economic harm directed at women or girls, driven by gender-based hatred, control, or discrimination
# Have the right to command
# Be respecting traditions
# Be behaving properly
# Stopping condition met for frame f411.
# Violence: Physical, emotional, psychological, sexual, or economic harm directed at women or girls, driven by gender-based hatred, control, or discrimination
# Have pleasure
# Have the right to command
# Stopping condition met for frame f2644.
# Violence: Physical, emotional, psychological, sexual, or economic harm directed at women or girls, driven by gender-based hatred, control, or discrimination
# Be respecting traditions
# Have the right to command
# Be just
# Stopping condition met for frame f271.
# Violence: Physical, emotional, psychological, sexual, or economic harm directed at women or girls, driven by gender-based hatred, control, or discrimination
# Have the right to command
# Have a stable society
# Be respecting traditions
# Stopping condition met for frame f1173.
# Violence: Physical, emotional, psychological, sexual, or economic harm directed at women or girls, driven by gender-based hatred, control, or discrimination
# Be respecting traditions
# Have a stable society
# Be compliant
# Have the right to command
# Stopping condition met for frame f7291.
# Violence: Physical, emotional, psychological, sexual, or economic harm directed at women or girls, driven by gender-based hatred, control, or discrimination
# Have the right to command
# Have pleasure
# Stopping condition met for frame f1657.
# Violence: Physical, emotional, psychological, sexual, or economic harm directed at women or girls, driven by gender-based hatred, control, or discrimination
# Be behaving properly
# Have the right to command
# Stopping condition met for frame f2762.
# Violence: Physical, emotional, psychological, sexual, or economic harm directed at women or girls, driven by gender-based hatred, control, or discrimination
# Have the right to command
# Have a good reputation
# Be respecting traditions
# Be polite
# Stopping condition met for frame f3109.
# Violence: Physical, emotional, psychological, sexual, or economic harm directed at women or girls, driven by gender-based hatred, control, or discrimination
# Have good health
# Have a stable society
# Be compliant
# Be polite
# Be respecting traditions
# Stopping condition met for frame f5836.
# Violence: Physical, emotional, psychological, sexual, or economic harm directed at women or girls, driven by gender-based hatred, control, or discrimination
# Be respecting traditions
# Be polite
# Have a stable society
# Have the right to command
# Stopping condition met for frame f359.
# Violence: Physical, emotional, psychological, sexual, or economic harm directed at women or girls, driven by gender-based hatred, control, or discrimination
# Have the right to command
# Be respecting traditions
# Stopping condition met for frame f897.
# Violence: Physical, emotional, psychological, sexual, or economic harm directed at women or girls, driven by gender-based hatred, control, or discrimination
# Be respecting traditions
# Have the right to command
# Stopping condition met for frame f1048.
# Violence: Physical, emotional, psychological, sexual, or economic harm directed at women or girls, driven by gender-based hatred, control, or discrimination
# Be respecting traditions
# Have a stable society
# Have a comfortable life
# Have the right to command
# Stopping condition met for frame f1050.
# Violence: Physical, emotional, psychological, sexual, or economic harm directed at women or girls, driven by gender-based hatred, control, or discrimination
# Be respecting traditions
# Be behaving properly
# Have a stable society
# Have a good reputation
# Have the right to command
# Stopping condition met for frame f1105.
# Violence: Physical, emotional, psychological, sexual, or economic harm directed at women or girls, driven by gender-based hatred, control, or discrimination
# Have the right to command
# Be respecting traditions
# Stopping condition met for frame f1162.
# Violence: Physical, emotional, psychological, sexual, or economic harm directed at women or girls, driven by gender-based hatred, control, or discrimination
# Have the right to command
# Stopping condition met for frame f1585.
# Violence: Physical, emotional, psychological, sexual, or economic harm directed at women or girls, driven by gender-based hatred, control, or discrimination
# Have the right to command
# Be respecting traditions
# Stopping condition met for frame f1648.
# Violence: Physical, emotional, psychological, sexual, or economic harm directed at women or girls, driven by gender-based hatred, control, or discrimination
# Have influence
# Stopping condition met for frame f1955.
# Violence: Physical, emotional, psychological, sexual, or economic harm directed at women or girls, driven by gender-based hatred, control, or discrimination
# Be just
# Have equality
# Be helpful
# Have good health
# Have a safe country
# Stopping condition met for frame f2207.
# Violence: Physical, emotional, psychological, sexual, or economic harm directed at women or girls, driven by gender-based hatred, control, or discrimination
# Have influence
# Be daring
# Stopping condition met for frame f2545.
# Violence: Physical, emotional, psychological, sexual, or economic harm directed at women or girls, driven by gender-based hatred, control, or discrimination
# Be respecting traditions
# Have a stable society
# Be behaving properly
# Have the right to command
# Stopping condition met for frame f2865.
# Violence: Physical, emotional, psychological, sexual, or economic harm directed at women or girls, driven by gender-based hatred, control, or discrimination
# Have the right to command
# Be respecting traditions
# Be compliant
# Stopping condition met for frame f3104.
# Violence: Physical, emotional, psychological, sexual, or economic harm directed at women or girls, driven by gender-based hatred, control, or discrimination
# Have the right to command
# Be compliant
# Stopping condition met for frame f3272.
# Violence: Physical, emotional, psychological, sexual, or economic harm directed at women or girls, driven by gender-based hatred, control, or discrimination
# Have the right to command
# Stopping condition met for frame f3285.
# Violence: Physical, emotional, psychological, sexual, or economic harm directed at women or girls, driven by gender-based hatred, control, or discrimination
# Have the right to command
# Stopping condition met for frame f4214.
# Violence: Physical, emotional, psychological, sexual, or economic harm directed at women or girls, driven by gender-based hatred, control, or discrimination
# Have the right to command
# Be respecting traditions
# Stopping condition met for frame f4879.
# Done violence problem
# Wage Disparity: Unequal pay that women receive compared to men for performing the same or similar work, which is often rooted in patriarchal systems that prioritize men's labor and devalue women's contributions
# Have wealth
# Stopping condition met for frame f1107.
# Wage Disparity: Unequal pay that women receive compared to men for performing the same or similar work, which is often rooted in patriarchal systems that prioritize men's labor and devalue women's contributions
# Have the right to command
# Be respecting traditions
# Stopping condition met for frame f4760.
# Wage Disparity: Unequal pay that women receive compared to men for performing the same or similar work, which is often rooted in patriarchal systems that prioritize men's labor and devalue women's contributions
# Be respecting traditions
# Have a stable society
# Have wealth
# Have the right to command
# Stopping condition met for frame f6705.
# Done wage_disparity problem
# Women Subjugation: Bringing women under domination or control, often through oppression or coercion
# Have the right to command
# Have influence
# Be respecting traditions
# Be compliant
# Have a stable society
# Stopping condition met for frame f5762.
# Women Subjugation: Bringing women under domination or control, often through oppression or coercion
# Be respecting traditions
# Have the right to command
# Stopping condition met for frame f3437.
# Women Subjugation: Bringing women under domination or control, often through oppression or coercion
# Be respecting traditions
# Be compliant
# Have the right to command
# Stopping condition met for frame f3274.
# Women Subjugation: Bringing women under domination or control, often through oppression or coercion
# Be respecting traditions
# Have the right to command
# Have a stable society
# Stopping condition met for frame f3741.
# Done women_subjugation problem
# Women Valuation: Practice of assigning women a value or status based on perceived traits
# Have the right to command
# Be respecting traditions
# Stopping condition met for frame f719.
# Women Valuation: Practice of assigning women a value or status based on perceived traits
# Have pleasure
# Stopping condition met for frame f158.
# Women Valuation: Practice of assigning women a value or status based on perceived traits
# Have social recognition
# Have a good reputation
# Stopping condition met for frame f2957.
# Women Valuation: Practice of assigning women a value or status based on perceived traits
# Have the right to command
# Stopping condition met for frame f4464.
# Women Valuation: Practice of assigning women a value or status based on perceived traits
# Have wealth
# Stopping condition met for frame f720.
# Done women_valuation problem
# Workplace Discrimination: Unfair or prejudicial treatment of female employees or female job applicants
# Uphold traditional gender roles
# Have the right to command
# Have pleasure from women’s appearance
# Stopping condition met for frame f297.
# Workplace Discrimination: Unfair or prejudicial treatment of female employees or female job applicants
# Be respecting traditions
# Have pleasure
# Stopping condition met for frame f540.
# Workplace Discrimination: Unfair or prejudicial treatment of female employees or female job applicants
# Have influence
# Be respecting traditions
# Have a stable society
# Stopping condition met for frame f1188.
# Workplace Discrimination: Unfair or prejudicial treatment of female employees or female job applicants
# be respecting traditions
# be compliant
# have the right to command
# Stopping condition met for frame f3441.
# Workplace Discrimination: Unfair or prejudicial treatment of female employees or female job applicants
# Ensure equality in professional assessment
# Uphold justice by valuing women's skills equally to men's
# Foster respect and validation for women's professional contributions
# Stopping condition met for frame f5186.
# Workplace Discrimination: Unfair or prejudicial treatment of female employees or female job applicants
# Be respecting traditions
# Be compliant
# Have a stable society
# Have the right to command
# Have wealth
# Stopping condition met for frame f5267.
# Demeaning Aspirations: Belittling, devaluing, or dismissing the goals and ambitions of women, based on traditional patriarchal norms
# Workplace Discrimination: Unfair or prejudicial treatment of female employees or female job applicants
# Be respecting traditions
# Be polite
# Have the right to command
# Stopping condition met for frame f5610.
# Exclusion: Deliberate or systemic marginalization of women from social, professional, political, or cultural opportunities and spaces
# Workplace Discrimination: Unfair or prejudicial treatment of female employees or female job applicants
# Be respecting traditions
# Be compliant
# Have the right to command
# Stopping condition met for frame f3911.
# Workplace Discrimination: Unfair or prejudicial treatment of female employees or female job applicants
# Have the right to command
# Be respecting traditions
# Stopping condition met for frame f5998.
# Done workplace_discrimination problem

# %%
problem_temp=[]
problem_temp.append({"id": idf,
            "frame": frame,
            "response": response.model_dump(),
            "history": [step.model_dump() for step in history.history],
        })
write_jsonl(os.path.join('values.jsonl'), problem_temp)

# %% [markdown]
# Confidence prediction

# %%
@dataclasses.dataclass
class ChatCompletionConfig:
    seed: int
    delay: int
    model: str
    max_tokens: int
    temperature: float
    system_prompt: str
    user_prompt: str
    response_format: dict | None = None

# %%
def make_user_prompt(frame, value, rationale, user):
    msg=[]
    msg.append({"role":"user","content": user.format(frame=frame, value=value, rationale=rationale)})
    return msg

# %%
results=[]
config_file_path = 'prompts/evaluate.yaml'
with open(config_file_path, 'r') as f:
    config = yaml.safe_load(f)
    config = ChatCompletionConfig(**config)
client = OpenAI(api_key=os.environ['OPENAI_API_KEY'], timeout=90)
sys_prompt = config.system_prompt.strip()
user_prompt= config.user_prompt.strip()
msg=[{"role": "system", "content": sys_prompt}]

# %%
for f in sorted(os.listdir('final_frames')):
    val_file=os.path.join('final_frames',f,'values.jsonl')
    for value in read_jsonl(val_file):
        frame_id = value['id']
        frame= value['frame']
        l=value['response']['values']
        if 'level_1_values' in l:
            for x in l['level_1_values']:
                msg.extend(make_user_prompt(msg, frame, x['level_1_value'], x['rationale'],user_prompt))
                try:
                    completion = client.chat.completions.create(
                        model=config.model,
                        messages=msg,
                        temperature=config.temperature,
                        seed=config.seed,
                        response_format=config.response_format,
                    )
                except Exception as e:
                    print(f"API call failed for {frame_id}: {e}")
                    msg.pop()
                    continue
                msg.pop()
                content = completion.choices[0].message.content
                results.append({'id':frame_id, 'frame': frame, 'value': x['level_1_value'], 'rationale': x['rationale'], 'judgement':content['judge']})
        
        if 'level_2_values' in l:
            for x in l['level_2_values']:
                msg.extend(make_user_prompt(msg, frame, x['level_2_value'], x['rationale'],user_prompt))
                try:
                    completion = client.chat.completions.create(
                        model=config.model,
                        messages=msg,
                        temperature=config.temperature,
                        seed=config.seed,
                        response_format=config.response_format,
                    )
                except Exception as e:
                    print(f"API call failed for {frame_id}: {e}")
                    msg.pop()
                    continue
                msg.pop()
                content = completion.choices[0].message.content
                results.append({'id':frame_id, 'frame': frame, 'value': x['level_2_value'], 'rationale': x['rationale'], 'judgement':content['judge']})
        
        if 'level_3_values' in l:
            for x in l['level_3_values']:
                msg.extend(make_user_prompt(msg, frame, x['level_3_value'], x['rationale'],user_prompt))
                try:
                    completion = client.chat.completions.create(
                        model=config.model,
                        messages=msg,
                        temperature=config.temperature,
                        seed=config.seed,
                        response_format=config.response_format,
                    )
                except Exception as e:
                    print(f"API call failed for {frame_id}: {e}")
                    msg.pop()
                    continue
                msg.pop()
                content = completion.choices[0].message.content
                results.append({'id':frame_id, 'frame': frame, 'value': x['level_3_value'], 'rationale': x['rationale'], 'judgement':content['judge']})

    print('Done with {f}')

# %%
write_jsonl('evaluations.jsonl', results)

# %% [markdown]
# Cleaning value_contra..replacing 'response' with response in 'history'

# %%
import json
import os

for f in sorted(os.listdir('final_frames')):
    input_file = os.path.join('final_frames',f,'values_contra.jsonl')
    output_file = os.path.join('final_frames',f,'values_contra2.jsonl')

    with open(input_file, "r", encoding="utf-8") as infile, \
        open(output_file, "w", encoding="utf-8") as outfile:

        for line in infile:
            entry = json.loads(line)

            if entry.get("history"):
                # Assuming you want the 'response' from the first history item
                first_history_response = entry["history"][0].get("response")
                if first_history_response:
                    entry["response"] = first_history_response

            # Write updated entry
            outfile.write(json.dumps(entry, ensure_ascii=False) + "\n")

    print(f"Updated file written to {output_file}")
# Out:
# Updated file written to final_frames/ableism/values_contra2.jsonl
# Updated file written to final_frames/age_related_sexualization/values_contra2.jsonl
# Updated file written to final_frames/ageism/values_contra2.jsonl
# Updated file written to final_frames/appearance_based_discrimination/values_contra2.jsonl
# Updated file written to final_frames/biased_judgement/values_contra2.jsonl
# Updated file written to final_frames/classism/values_contra2.jsonl
# Updated file written to final_frames/coercion/values_contra2.jsonl
# Updated file written to final_frames/commitment_phobia/values_contra2.jsonl
# Updated file written to final_frames/conditional_respect/values_contra2.jsonl
# Updated file written to final_frames/conspiracy_thinking/values_contra2.jsonl
# Updated file written to final_frames/cultural_insensitivity/values_contra2.jsonl
# Updated file written to final_frames/deflection/values_contra2.jsonl
# Updated file written to final_frames/dehumanization_of_women/values_contra2.jsonl
# Updated file written to final_frames/demeaning_aspirations/values_contra2.jsonl
# Updated file written to final_frames/demonization/values_contra2.jsonl
# Updated file written to final_frames/derogatory_labeling/values_contra2.jsonl
# Updated file written to final_frames/discrimination/values_contra2.jsonl
# Updated file written to final_frames/dismissing_women_s_rights/values_contra2.jsonl
# Updated file written to final_frames/dismissiveness/values_contra2.jsonl
# Updated file written to final_frames/disposability/values_contra2.jsonl
# Updated file written to final_frames/disrespect_towards_women/values_contra2.jsonl
# Updated file written to final_frames/disrespecting_sex_workers/values_contra2.jsonl
# Updated file written to final_frames/double_standards/values_contra2.jsonl
# Updated file written to final_frames/endorsing_marital_rape/values_contra2.jsonl
# Updated file written to final_frames/endorsing_necrophilia/values_contra2.jsonl
# Updated file written to final_frames/enforced_gender_norms/values_contra2.jsonl
# Updated file written to final_frames/exclusion/values_contra2.jsonl
# Updated file written to final_frames/exploitation_of_women_by_men/values_contra2.jsonl
# Updated file written to final_frames/false_accusations/values_contra2.jsonl
# Updated file written to final_frames/false_equivalence/values_contra2.jsonl
# Updated file written to final_frames/fat_shaming/values_contra2.jsonl
# Updated file written to final_frames/fearmongering/values_contra2.jsonl
# Updated file written to final_frames/forced_marriage/values_contra2.jsonl
# Updated file written to final_frames/gatekeeping/values_contra2.jsonl
# Updated file written to final_frames/gender_essentialism/values_contra2.jsonl
# Updated file written to final_frames/homophobia/values_contra2.jsonl
# Updated file written to final_frames/incest/values_contra2.jsonl
# Updated file written to final_frames/intellectual_degradation/values_contra2.jsonl
# Updated file written to final_frames/intersectional_prejudice/values_contra2.jsonl
# Updated file written to final_frames/invalidating_women_s_experiences/values_contra2.jsonl
# Updated file written to final_frames/lack_of_accountability_by_men/values_contra2.jsonl
# Updated file written to final_frames/male_validation/values_contra2.jsonl
# Updated file written to final_frames/menstruation_stigma/values_contra2.jsonl
# Updated file written to final_frames/minimizing_feminist_efforts/values_contra2.jsonl
# Updated file written to final_frames/misrepresentation/values_contra2.jsonl
# Updated file written to final_frames/mistrust_in_women/values_contra2.jsonl
# Updated file written to final_frames/misunderstanding_feminism/values_contra2.jsonl
# Updated file written to final_frames/neo_sexism/values_contra2.jsonl
# Updated file written to final_frames/objectification/values_contra2.jsonl
# Updated file written to final_frames/ownership/values_contra2.jsonl
# Updated file written to final_frames/patriarchal_attitudes/values_contra2.jsonl
# Updated file written to final_frames/patriarchal_control/values_contra2.jsonl
# Updated file written to final_frames/pedophilia_exploitation/values_contra2.jsonl
# Updated file written to final_frames/policing_women_s_bodies/values_contra2.jsonl
# Updated file written to final_frames/possessiveness/values_contra2.jsonl
# Updated file written to final_frames/professional_misconduct/values_contra2.jsonl
# Updated file written to final_frames/promoting_infidelity/values_contra2.jsonl
# Updated file written to final_frames/promoting_rape_culture/values_contra2.jsonl
# Updated file written to final_frames/promoting_self_harm/values_contra2.jsonl
# Updated file written to final_frames/racism/values_contra2.jsonl
# Updated file written to final_frames/reductionism/values_contra2.jsonl
# Updated file written to final_frames/reverse_sexism/values_contra2.jsonl
# Updated file written to final_frames/ridicule/values_contra2.jsonl
# Updated file written to final_frames/scapegoating/values_contra2.jsonl
# Updated file written to final_frames/sexist_pseudoscience/values_contra2.jsonl
# Updated file written to final_frames/sexual_entitlement/values_contra2.jsonl
# Updated file written to final_frames/sexual_harassment/values_contra2.jsonl
# Updated file written to final_frames/sexual_innuendo/values_contra2.jsonl
# Updated file written to final_frames/sexualization/values_contra2.jsonl
# Updated file written to final_frames/single_motherhood_stigmatization/values_contra2.jsonl
# Updated file written to final_frames/stereotyping/values_contra2.jsonl
# Updated file written to final_frames/stigmatization/values_contra2.jsonl
# Updated file written to final_frames/toxic_masculinity/values_contra2.jsonl
# Updated file written to final_frames/transactional_relationships/values_contra2.jsonl
# Updated file written to final_frames/transphobia/values_contra2.jsonl
# Updated file written to final_frames/trivializing_addiction/values_contra2.jsonl
# Updated file written to final_frames/trivializing_consent/values_contra2.jsonl
# Updated file written to final_frames/trivializing_eating_disorders/values_contra2.jsonl
# Updated file written to final_frames/trivializing_infidelity/values_contra2.jsonl
# Updated file written to final_frames/trivializing_mental_health_issues/values_contra2.jsonl
# Updated file written to final_frames/trivializing_oppression/values_contra2.jsonl
# Updated file written to final_frames/trivializing_prostitution/values_contra2.jsonl
# Updated file written to final_frames/trivializing_serious_issues/values_contra2.jsonl
# Updated file written to final_frames/trivializing_sexual_assault/values_contra2.jsonl
# Updated file written to final_frames/trivializing_the_need_for_representation/values_contra2.jsonl
# Updated file written to final_frames/trivializing_women_s_issues/values_contra2.jsonl
# Updated file written to final_frames/trivializing_women_s_sexual_satisfaction/values_contra2.jsonl
# Updated file written to final_frames/undermining_women_s_capabilities/values_contra2.jsonl
# Updated file written to final_frames/undermining_women_s_rights_movements/values_contra2.jsonl
# Updated file written to final_frames/unrealistic_beauty_standards/values_contra2.jsonl
# Updated file written to final_frames/victim_blaming/values_contra2.jsonl
# Updated file written to final_frames/violence/values_contra2.jsonl
# Updated file written to final_frames/wage_disparity/values_contra2.jsonl
# Updated file written to final_frames/women_subjugation/values_contra2.jsonl
# Updated file written to final_frames/women_valuation/values_contra2.jsonl
# Updated file written to final_frames/workplace_discrimination/values_contra2.jsonl

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import os
import math

image_folder = 'TRAINING'
sources = ["8624.jpg", "9056.jpg", "1528.jpg", "9043.jpg", "9593.jpg", "9502.jpg", "3469.jpg", "10286.jpg", "370.jpg", "3571.jpg", "3837.jpg", "11057.jpg", "375.jpg", "3959.jpg", "3960.jpg", "6832.jpg", "8073.jpg", "5768.jpg", "13333.jpg", "10532.jpg", "1339.jpg", "3330.jpg", "1015.jpg", "5723.jpg", "523.jpg", "3019.jpg", "1336.jpg", "7779.jpg", "4928.jpg", "1011.jpg", "2666.jpg", "3215.jpg", "3612.jpg", "6920.jpg", "2686.jpg", "8362.jpg", "7655.jpg", "389.jpg", "1434.jpg", "2749.jpg", "5167.jpg", "872.jpg", "11543.jpg", "4505.jpg", "11176.jpg", "9146.jpg", "5277.jpg", "10923.jpg", "6160.jpg", "7398.jpg", "1115.jpg", "11551.jpg", "1272.jpg", "2592.jpg", "4945.jpg", "885.jpg", "4913.jpg", "2231.jpg", "10810.jpg", "8221.jpg", "695.jpg", "9456.jpg", "3588.jpg", "1509.jpg", "10177.jpg", "9134.jpg", "4530.jpg", "10486.jpg", "7314.jpg", "8755.jpg", "5116.jpg", "11208.jpg", "6602.jpg", "3861.jpg", "8193.jpg", "1970.jpg", "3943.jpg", "7782.jpg", "4450.jpg", "8659.jpg", "478.jpg", "7347.jpg", "9770.jpg", "6677.jpg", "1349.jpg", "3105.jpg", "6436.jpg", "5472.jpg", "5665.jpg", "4751.jpg", "5303.jpg", "8693.jpg", "5699.jpg", "1564.jpg", "9296.jpg", "2543.jpg", "2483.jpg", "4784.jpg", "4772.jpg", "5018.jpg", "1464.jpg", "7021.jpg", "10187.jpg", "5606.jpg", "1567.jpg", "9444.jpg", "97.jpg", "1504.jpg", "1376.jpg", "5607.jpg", "14155.jpg", "6297.jpg", "2844.jpg", "5488.jpg", "142.jpg", "9044.jpg", "10998.jpg", "7167.jpg", "4970.jpg", "8581.jpg", "4229.jpg", "10977.jpg", "6381.jpg", "6728.jpg", "10.jpg", "7772.jpg", "6599.jpg", "9253.jpg", "2834.jpg"]
num_images = len(sources)
cols = 4
rows = math.ceil(num_images / cols)
fig, axes = plt.subplots(rows, cols, figsize=(16, rows * 4))

axes = axes.flatten() if num_images > 1 else [axes]

for idx, ax in enumerate(axes):
    if idx < num_images:
        img_path = os.path.join(image_folder, sources[idx])
        img = mpimg.imread(img_path)
        ax.imshow(img)
        ax.set_title(sources[idx], fontsize=10)
        ax.axis('off')
    else:
        ax.axis('off')  # Hide unused subplots

plt.tight_layout()
plt.show()

# %%
len(sources)
# Out:
# 129
